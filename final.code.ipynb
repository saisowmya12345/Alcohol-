# %%
import os
os.getcwd()
# Out:
# 'C:\\Users\\phanivarma\\Desktop\\data sets'

# %%
os.chdir("C:/Users/phanivarma/Desktop/data sets")
os.getcwd()
# Out:
# 'C:\\Users\\phanivarma\\Desktop\\data sets'

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
# %matplotlib inline
s=pd.read_csv("airquality.csv")
s
# Out:
#      Ozone  Solar.R  Wind  Temp  Month  Day
# 0     41.0    190.0   7.4    67      5    1
# 1     36.0    118.0   8.0    72      5    2
# 2     12.0    149.0  12.6    74      5    3
# 3     18.0    313.0  11.5    62      5    4
# 4      NaN      NaN  14.3    56      5    5
# 5     28.0      NaN  14.9    66      5    6
# 6     23.0    299.0   8.6    65      5    7
# 7     19.0     99.0  13.8    59      5    8
# 8      8.0     19.0  20.1    61      5    9
# 9      NaN    194.0   8.6    69      5   10
# 10     7.0      NaN   6.9    74      5   11
# 11    16.0    256.0   9.7    69      5   12
# 12    11.0    290.0   9.2    66      5   13
# 13    14.0    274.0  10.9    68      5   14
# 14    18.0     65.0  13.2    58      5   15
# 15    14.0    334.0  11.5    64      5   16
# 16    34.0    307.0  12.0    66      5   17
# 17     6.0     78.0  18.4    57      5   18
# 18    30.0    322.0  11.5    68      5   19
# 19    11.0     44.0   9.7    62      5   20
# ...

# %%
s['Ozone'].min()
# Out:
# 1.0

# %%
s['Ozone'].max()
# Out:
# 168.0

# %%
mean_Ozone=s['Ozone'].mean()
mean_Ozone
# Out:
# 42.12931034482759

# %%
median_Ozone=s['Ozone'].median()
median_Ozone
# Out:
# 31.5

# %%
np.std(s['Ozone'])
# Out:
# 32.845387586863275

# %%
np.var(s['Ozone'])
# Out:
# 1078.8194857312722

# %%
s.boxplot(column='Ozone')

# %%
s.apply(lambda x:sum(x.isnull()),axis=0)
# Out:
# Ozone      37
# Solar.R     7
# Wind        0
# Temp        0
# Month       0
# Day         0
# dtype: int64

# %%
feature=s.iloc[:,1:].values
feature
# Out:
# array([[190. ,   7.4,  67. ,   5. ,   1. ],
#        [118. ,   8. ,  72. ,   5. ,   2. ],
#        [149. ,  12.6,  74. ,   5. ,   3. ],
#        [313. ,  11.5,  62. ,   5. ,   4. ],
#        [  nan,  14.3,  56. ,   5. ,   5. ],
#        [  nan,  14.9,  66. ,   5. ,   6. ],
#        [299. ,   8.6,  65. ,   5. ,   7. ],
#        [ 99. ,  13.8,  59. ,   5. ,   8. ],
#        [ 19. ,  20.1,  61. ,   5. ,   9. ],
#        [194. ,   8.6,  69. ,   5. ,  10. ],
#        [  nan,   6.9,  74. ,   5. ,  11. ],
#        [256. ,   9.7,  69. ,   5. ,  12. ],
#        [290. ,   9.2,  66. ,   5. ,  13. ],
#        [274. ,  10.9,  68. ,   5. ,  14. ],
#        [ 65. ,  13.2,  58. ,   5. ,  15. ],
#        [334. ,  11.5,  64. ,   5. ,  16. ],
#        [307. ,  12. ,  66. ,   5. ,  17. ],
#        [ 78. ,  18.4,  57. ,   5. ,  18. ],
#        [322. ,  11.5,  68. ,   5. ,  19. ],
#        [ 44. ,   9.7,  62. ,   5. ,  20. ],
#        [  8. ,   9.7,  59. ,   5. ,  21. ],
# ...

# %%
labels=s.iloc[:,0:1].values
labels
# Out:
# array([[ 41.],
#        [ 36.],
#        [ 12.],
#        [ 18.],
#        [ nan],
#        [ 28.],
#        [ 23.],
#        [ 19.],
#        [  8.],
#        [ nan],
#        [  7.],
#        [ 16.],
#        [ 11.],
#        [ 14.],
#        [ 18.],
#        [ 14.],
#        [ 34.],
#        [  6.],
#        [ 30.],
#        [ 11.],
#        [  1.],
#        [ 11.],
#        [  4.],
#        [ 32.],
#        [ nan],
#        [ nan],
#        [ nan],
#        [ 23.],
#        [ 45.],
#        [115.],
#        [ 37.],
#        [ nan],
#        [ nan],
#        [ nan],
#        [ nan],
#        [ nan],
#        [ nan],
#        [ 29.],
#        [ nan],
#        [ 71.],
#        [ 39.],
#        [ nan],
#        [ nan],
#        [ 23.],
#        [ nan],
#        [ nan],
#        [ 21.],
#        [ 37.],
#        [ 20.],
#        [ 12.],
#        [ 13.],
#        [ nan],
#        [ nan],
#        [ nan],
#        [ nan],
#        [ nan],
#        [ nan],
#        [ nan],
# ...

# %%
from sklearn.preprocessing import Imputer
Imputer=Imputer(missing_values='NaN',strategy='mean',axis=0)
Imputer
# Out:
# C:\Users\phanivarma\Anaconda3\lib\site-packages\sklearn\utils\deprecation.py:58: DeprecationWarning: Class Imputer is deprecated; Imputer was deprecated in version 0.20 and will be removed in 0.22. Import impute.SimpleImputer from sklearn instead.
#   warnings.warn(msg, category=DeprecationWarning)
# Imputer(axis=0, copy=True, missing_values='NaN', strategy='mean', verbose=0)

# %%
Imputer.fit(feature[:,[0]])
feature[:,[0]]=Imputer.fit_transform(feature[:,[0]])
feature[:,[0]]
# Out:
# array([[190.        ],
#        [118.        ],
#        [149.        ],
#        [313.        ],
#        [185.93150685],
#        [185.93150685],
#        [299.        ],
#        [ 99.        ],
#        [ 19.        ],
#        [194.        ],
#        [185.93150685],
#        [256.        ],
#        [290.        ],
#        [274.        ],
#        [ 65.        ],
#        [334.        ],
#        [307.        ],
#        [ 78.        ],
#        [322.        ],
#        [ 44.        ],
#        [  8.        ],
#        [320.        ],
#        [ 25.        ],
#        [ 92.        ],
#        [ 66.        ],
#        [266.        ],
#        [185.93150685],
#        [ 13.        ],
#        [252.        ],
#        [223.        ],
#        [279.        ],
#        [286.        ],
#        [287.        ],
#        [242.        ],
#        [186.        ],
#        [220.        ],
#        [264.        ],
#        [127.        ],
#        [273.        ],
#        [291.        ],
# ...

# %%
df1=pd.DataFrame(feature)
df1.apply(lambda x:sum(x.isnull()),axis=0)
# Out:
# 0    0
# 1    0
# 2    0
# 3    0
# 4    0
# dtype: int64

# %%
Imputer.fit(labels[:,[0]])
labels[:,[0]]=Imputer.fit_transform(labels[:,[0]])
labels[:,[0]]
# Out:
# array([[ 41.        ],
#        [ 36.        ],
#        [ 12.        ],
#        [ 18.        ],
#        [ 42.12931034],
#        [ 28.        ],
#        [ 23.        ],
#        [ 19.        ],
#        [  8.        ],
#        [ 42.12931034],
#        [  7.        ],
#        [ 16.        ],
#        [ 11.        ],
#        [ 14.        ],
#        [ 18.        ],
#        [ 14.        ],
#        [ 34.        ],
#        [  6.        ],
#        [ 30.        ],
#        [ 11.        ],
#        [  1.        ],
#        [ 11.        ],
#        [  4.        ],
#        [ 32.        ],
#        [ 42.12931034],
#        [ 42.12931034],
#        [ 42.12931034],
#        [ 23.        ],
#        [ 45.        ],
#        [115.        ],
#        [ 37.        ],
#        [ 42.12931034],
#        [ 42.12931034],
#        [ 42.12931034],
#        [ 42.12931034],
#        [ 42.12931034],
#        [ 42.12931034],
#        [ 29.        ],
#        [ 42.12931034],
#        [ 71.        ],
# ...

# %%
df2=pd.DataFrame(labels)
df2.apply(lambda x:sum(x.isnull()),axis=0)
# Out:
# 0    0
# dtype: int64

# %%
x1=df1
y1=df2

# %%
x1
# Out:
#               0     1     2    3     4
# 0    190.000000   7.4  67.0  5.0   1.0
# 1    118.000000   8.0  72.0  5.0   2.0
# 2    149.000000  12.6  74.0  5.0   3.0
# 3    313.000000  11.5  62.0  5.0   4.0
# 4    185.931507  14.3  56.0  5.0   5.0
# 5    185.931507  14.9  66.0  5.0   6.0
# 6    299.000000   8.6  65.0  5.0   7.0
# 7     99.000000  13.8  59.0  5.0   8.0
# 8     19.000000  20.1  61.0  5.0   9.0
# 9    194.000000   8.6  69.0  5.0  10.0
# 10   185.931507   6.9  74.0  5.0  11.0
# 11   256.000000   9.7  69.0  5.0  12.0
# 12   290.000000   9.2  66.0  5.0  13.0
# 13   274.000000  10.9  68.0  5.0  14.0
# 14    65.000000  13.2  58.0  5.0  15.0
# 15   334.000000  11.5  64.0  5.0  16.0
# 16   307.000000  12.0  66.0  5.0  17.0
# 17    78.000000  18.4  57.0  5.0  18.0
# 18   322.000000  11.5  68.0  5.0  19.0
# 19    44.000000   9.7  62.0  5.0  20.0
# 20     8.000000   9.7  59.0  5.0  21.0
# 21   320.000000  16.6  73.0  5.0  22.0
# 22    25.000000   9.7  61.0  5.0  23.0
# ...

# %%
y1
# Out:
#              0
# 0     41.00000
# 1     36.00000
# 2     12.00000
# 3     18.00000
# 4     42.12931
# 5     28.00000
# 6     23.00000
# 7     19.00000
# 8      8.00000
# 9     42.12931
# 10     7.00000
# 11    16.00000
# 12    11.00000
# 13    14.00000
# 14    18.00000
# 15    14.00000
# 16    34.00000
# 17     6.00000
# 18    30.00000
# 19    11.00000
# 20     1.00000
# 21    11.00000
# 22     4.00000
# 23    32.00000
# 24    42.12931
# 25    42.12931
# 26    42.12931
# 27    23.00000
# 28    45.00000
# 29   115.00000
# ..         ...
# 123   96.00000
# 124   78.00000
# 125   73.00000
# 126   91.00000
# 127   47.00000
# 128   32.00000
# 129   20.00000
# 130   23.00000
# 131   21.00000
# 132   24.00000
# 133   44.00000
# 134   21.00000
# 135   28.00000
# 136    9.00000
# 137   13.00000
# 138   46.00000
# 139   18.00000
# 140   13.00000
# 141   24.00000
# 142   16.00000
# 143   13.00000
# 144   23.00000
# 145   36.00000
# 146    7.00000
# 147   14.00000
# 148   30.00000
# ...

# %%
from sklearn.preprocessing import Imputer
Imputer=Imputer(missing_values='NaN',strategy='mean',axis=0)
Imputer
# Out:
# C:\Users\phanivarma\Anaconda3\lib\site-packages\sklearn\utils\deprecation.py:58: DeprecationWarning: Class Imputer is deprecated; Imputer was deprecated in version 0.20 and will be removed in 0.22. Import impute.SimpleImputer from sklearn instead.
#   warnings.warn(msg, category=DeprecationWarning)
# Imputer(axis=0, copy=True, missing_values='NaN', strategy='mean', verbose=0)

# %%
Imputer.fit(feature[:,[0,1]])
feature[:,[0,1]]=Imputer.fit_transform(feature[:,[0,1]])
feature[:,[0,1]]
# Out:
# array([[ 41.        , 190.        ],
#        [ 36.        , 118.        ],
#        [ 12.        , 149.        ],
#        [ 18.        , 313.        ],
#        [ 42.12931034, 185.93150685],
#        [ 28.        , 185.93150685],
#        [ 23.        , 299.        ],
#        [ 19.        ,  99.        ],
#        [  8.        ,  19.        ],
#        [ 42.12931034, 194.        ],
#        [  7.        , 185.93150685],
#        [ 16.        , 256.        ],
#        [ 11.        , 290.        ],
#        [ 14.        , 274.        ],
#        [ 18.        ,  65.        ],
#        [ 14.        , 334.        ],
#        [ 34.        , 307.        ],
#        [  6.        ,  78.        ],
#        [ 30.        , 322.        ],
#        [ 11.        ,  44.        ],
#        [  1.        ,   8.        ],
#        [ 11.        , 320.        ],
#        [  4.        ,  25.        ],
#        [ 32.        ,  92.        ],
#        [ 42.12931034,  66.        ],
# ...

# %%
X=s[['Solar.R','Wind','Temp','Month','Day']]
y=s['Ozone']

# %%
X1=s[['Solar.R','Wind','Temp','Month','Day']]
y1=s['Ozone']

# %%
#split data
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.4,random_state=1)

# %%
feature=X_train.iloc[:,:].values

# %%
labels=y_train.iloc[:].values

# %%
X=feature
y=labels

# %%
from sklearn import linear_model as lm
model=lm.LinearRegression()
results=model.fit(X,y)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-35-f6de7191e46f> in <module>
#       1 from sklearn import linear_model as lm
#       2 model=lm.LinearRegression()
# ----> 3 results=model.fit(X,y)
#
# ~\Anaconda3\lib\site-packages\sklearn\linear_model\base.py in fit(self, X, y, sample_weight)
#     456         n_jobs_ = self.n_jobs
#     457         X, y = check_X_y(X, y, accept_sparse=['csr', 'csc', 'coo'],
# --> 458                          y_numeric=True, multi_output=True)
#     459
#     460         if sample_weight is not None and np.atleast_1d(sample_weight).ndim > 1:
#
# ~\Anaconda3\lib\site-packages\sklearn\utils\validation.py in check_X_y(X, y, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, multi_output, ensure_min_samples, ensure_min_features, y_numeric, warn_on_dtype, estimator)
# ...

# %%
predictions=model.predict(X)
# Out:
# ---------------------------------------------------------------------------
# NotFittedError                            Traceback (most recent call last)
# <ipython-input-33-4402b7bb1118> in <module>
# ----> 1 predictions=model.predict(X)
#
# ~\Anaconda3\lib\site-packages\sklearn\linear_model\base.py in predict(self, X)
#     211             Returns predicted values.
#     212         """
# --> 213         return self._decision_function(X)
#     214
#     215     _preprocess_data = staticmethod(_preprocess_data)
#
# ~\Anaconda3\lib\site-packages\sklearn\linear_model\base.py in _decision_function(self, X)
#     192
#     193     def _decision_function(self, X):
# --> 194         check_is_fitted(self, "coef_")
#     195
#     196         X = check_array(X, accept_sparse=['csr', 'csc', 'coo'])
#
# ~\Anaconda3\lib\site-packages\sklearn\utils\validation.py in check_is_fitted(estimator, attributes, msg, all_or_any)
#     949
# ...

# %%
accuracy=model.score(X,y)
print('Accuracy of the model:',accuracy)
# Out:
# ---------------------------------------------------------------------------
# NotFittedError                            Traceback (most recent call last)
# <ipython-input-36-47e640933235> in <module>
# ----> 1 accuracy=model.score(X,y)
#       2 print('Accuracy of the model:',accuracy)
#
# ~\Anaconda3\lib\site-packages\sklearn\base.py in score(self, X, y, sample_weight)
#     326
#     327         from .metrics import r2_score
# --> 328         return r2_score(y, self.predict(X), sample_weight=sample_weight,
#     329                         multioutput='variance_weighted')
#     330
#
# ~\Anaconda3\lib\site-packages\sklearn\linear_model\base.py in predict(self, X)
#     211             Returns predicted values.
#     212         """
# --> 213         return self._decision_function(X)
#     214
#     215     _preprocess_data = staticmethod(_preprocess_data)
#
# ~\Anaconda3\lib\site-packages\sklearn\linear_model\base.py in _decision_function(self, X)
#     192
# ...

# %%
plt.scatter(y,predictions)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-37-e494467ba786> in <module>
# ----> 1 plt.scatter(y,predictions)
#
# NameError: name 'predictions' is not defined

# %%
#evaluating the model
from sklearn.metrics import mean_squared_error,r2_score
print('slope:',model.coef_)
print('intercept:',model.intercept_)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-38-72a79f59eaae> in <module>
#       1 #evaluating the model
#       2 from sklearn.metrics import mean_squared_error,r2_score
# ----> 3 print('slope:',model.coef_)
#       4 print('intercept:',model.intercept_)
#
# AttributeError: 'LinearRegression' object has no attribute 'coef_'

# %%
import numpy as np
rmse=(np.sqrt(mean_squared_error(y,predictions)))
r2=r2_score(y,predictions)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-39-d7cdf0f094e1> in <module>
#       1 import numpy as np
# ----> 2 rmse=(np.sqrt(mean_squared_error(y,predictions)))
#       3 r2=r2_score(y,predictions)
#
# NameError: name 'predictions' is not defined

# %%
print("the model performance")
print("-----------------")
print("RMSE is()".format(rmse))
print("R2 score is()".format(r2))
# Out:
# the model performance
# -----------------
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-40-93c5dd31847d> in <module>
#       1 print("the model performance")
#       2 print("-----------------")
# ----> 3 print("RMSE is()".format(rmse))
#       4 print("R2 score is()".format(r2))
#
# NameError: name 'rmse' is not defined
